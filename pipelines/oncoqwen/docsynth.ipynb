# %% [markdown]
# ### Oncoqwen: Synthetic document generation

# %% [markdown]
# Set up environment (including `assume --env` credentials if required)

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %% [markdown]
# ### Import generator

# %%
from docsynth.generate import Generator
generator: Generator = Generator()

# %% [markdown]
# ### Generate documents (AWS Bedrock Sonnet batch)

# %%
generator.generate_via_batch(os.environ["BUCKET"], os.environ["BEDROCK_EXECUTION_ROLE"])

# %% [markdown]
# ### Download, parse and re-upload batch

# %%
generator.extract_batch_output(os.environ["BUCKET"])
